# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Import Data

# %% [markdown]
# Import each given data and engineered data using pandas library :

# %%
app_test = pd.read_csv('./Dataset/DS1/app_test.csv')
app_train = pd.read_csv('./Dataset/DS1/app_train.csv')
ins_prev = pd.read_csv('./ins_prev.csv')

# %% [markdown]
# ### Exploratory Data Analysis

# %% [markdown]
# Shape of each data :

# %%
print("app_test shape :", app_test.shape)
print("app_train shape :", app_train.shape)
print("ins_prev shape :", ins_prev.shape)
# Out:
# app_test shape : (14761, 24)
# app_train shape : (61503, 24)
# ins_prev shape : (350712, 22)

# %% [markdown]
# Descriptive statistics include those that summarize the central tendency, dispersion and shape of a dataset’s distribution, excluding NaN values.

# %%
app_train.describe()
# Out:
#           Unnamed: 0          LN_ID        TARGET  NUM_CHILDREN        INCOME  \
# count   61503.000000   61503.000000  61503.000000  61503.000000  6.150300e+04
# mean   153729.986927  278151.136416      0.080793      0.411850  1.690789e+05
# std     88881.478853  102918.206671      0.272519      0.716686  1.339697e+05
# min         6.000000  100009.000000      0.000000      0.000000  2.610000e+04
# 25%     76545.500000  188767.000000      0.000000      0.000000  1.125000e+05
# 50%    153893.000000  278357.000000      0.000000      0.000000  1.485000e+05
# 75%    230884.500000  367424.500000      0.000000      1.000000  2.025000e+05
# max    307510.000000  456255.000000      1.000000      9.000000  1.800009e+07
#
#        APPROVED_CREDIT        ANNUITY         PRICE      DAYS_AGE  \
# count     6.150300e+04   61502.000000  6.144100e+04  61503.000000
# mean      5.976899e+05   27083.323315  5.369033e+05 -16057.481033
# std       4.016493e+05   14470.508291  3.685742e+05   4363.536919
# ...

# %%
app_test.describe()
# Out:
#           Unnamed: 0          LN_ID        TARGET  NUM_CHILDREN        INCOME  \
# count   14761.000000   14761.000000  14761.000000  14761.000000  1.476100e+04
# mean   154253.864643  278759.502879      0.081499      0.411828  1.674965e+05
# std     88185.627857  102112.465678      0.273608      0.709092  9.538766e+04
# min        47.000000  100054.000000      0.000000      0.000000  2.655000e+04
# 25%     78418.000000  190910.000000      0.000000      0.000000  1.125000e+05
# 50%    154391.000000  278940.000000      0.000000      0.000000  1.440000e+05
# 75%    230217.000000  366655.000000      0.000000      1.000000  2.025000e+05
# max    307505.000000  456249.000000      1.000000      5.000000  2.930026e+06
#
#        APPROVED_CREDIT        ANNUITY         PRICE      DAYS_AGE  \
# count     1.476100e+04   14761.000000  1.474100e+04  14761.000000
# mean      5.961318e+05   27127.497764  5.361929e+05 -16024.982115
# std       3.996861e+05   14473.650999  3.665194e+05   4369.316681
# ...

# %%
ins_prev.describe()
# Out:
#                LN_ID        ANNUITY   APPLICATION  APPROVED_CREDIT  \
# count  350712.000000  274103.000000  3.507120e+05     3.507120e+05
# mean   278626.100136   15793.209924  1.747205e+05     1.958564e+05
# std    102733.229023   14601.033712  2.924484e+05     3.185176e+05
# min    100009.000000       0.000000  0.000000e+00     0.000000e+00
# 25%    189728.000000    6258.915000  1.957500e+04     2.473650e+04
# 50%    279204.000000   11201.085000  7.029000e+04     8.009285e+04
# 75%    367667.250000   20356.065000  1.800000e+05     2.156400e+05
# max    456255.000000  418058.145000  4.050000e+06     4.104351e+06
#
#        AMT_DOWN_PAYMENT         PRICE     HOUR_APPLY  DAYS_DECISION  \
# count      1.642050e+05  2.710720e+05  350712.000000  350712.000000
# mean       6.667307e+03  2.260759e+05      12.474438    -877.824856
# std        2.024318e+04  3.147324e+05       3.326745     781.578114
# min       -4.500000e-01  0.000000e+00       0.000000   -2922.000000
# ...
